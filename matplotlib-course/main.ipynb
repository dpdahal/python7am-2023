# %%
# import matplotlib.pyplot as plt

# fruits = ['apple', 'banana', 'orange', 'grape', 'strawberry']
# price = [100, 200, 150, 300, 120]
# # plt.bar(fruits, price,color=['red','yellow','orange','purple','pink'])
# plt.bar(fruits, price,width=0.2,color=['red','yellow','orange','purple','pink'])

# plt.title('Fruits Price')
# plt.xlabel('Fruit names')
# plt.ylabel('Price')
# # plt.legend(['banana'])
# plt.legend(['banana'])
# plt.show()

# django,flassk,pyramid,web2py

import requests

url = 'https://jsonplaceholder.typicode.com/users'
response = requests.get(url)
data = response.json()
data
# get zipcode
zipcode = []
for i in data:
    zipcode.append(i['address']['zipcode'])

# country name
city = []
for i in data:
    city.append(i['address']['city'])



import matplotlib.pyplot as plt

plt.bar(city, zipcode)
plt.title('Zipcode')

plt.show()
